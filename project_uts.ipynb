# %% [markdown]
# <a href="https://colab.research.google.com/github/dwyu0/uts_Strukturdata_dewayu_klsA/blob/main/project_uts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INISIALISASI

# %%
queue = []
max_size = 5

# %% [markdown]
# ENQUEUE (MENAMBAHKAN ANTRIAN)

# %%
def enqueue(data):
  if len(queue)>=max_size:
    print("ANTRIAN PENUH!")
  else:
    queue.append(data)
    print("Ditambahkan keantrian:",data)

# %% [markdown]
# DEQUEUE (PROSES ANTRIAN)

# %%
def dequeue():
  if not queue:
    print("Antrian kosong")
  else:
    print("Sudah di proses:",queue.pop(0))

# %% [markdown]
# DISPLAY (MENAMPILKAN SEMUA DATA)

# %%
def display():
  if not queue:
    print("Antrian kosong")
  else:
    print("\n Daftar antrian peminjaman:")
    for i, data in enumerate(queue):
      print(i+1,".",data)

# %% [markdown]
# PEEK (MELIHAT ANTRIAN TERDEPAN)

# %%
def peek():
  if queue:
    print("Antrian terdepan:",queue[0])
  else:
    print("Antrian kosong")

# %% [markdown]
# PENGAPLIKASIAN

# %%
enqueue ("Era minjem ruangan 515, jam 10.00-12.20 untuk rapat organisasi")
enqueue ("Wilsa minjem ruangan 331, jam 07.30-10.00 untuk kelas pengganti")
enqueue ("ceri minjem ruangan lab k, jam 10.00-12.20 untuk membuat web")

display()
peek()
dequeue()
display()
# Out:
# Ditambahkan keantrian: Era minjem ruangan 515, jam 10.00-12.20 untuk rapat organisasi
# Ditambahkan keantrian: Wilsa minjem ruangan 331, jam 07.30-10.00 untuk kelas pengganti
# Ditambahkan keantrian: ceri minjem ruangan lab k, jam 10.00-12.20 untuk membuat web
#
#  Daftar antrian peminjaman:
# 1 . Era minjem ruangan 515, jam 10.00-12.20 untuk rapat organisasi
# 2 . Wilsa minjem ruangan 331, jam 07.30-10.00 untuk kelas pengganti
# 3 . ceri minjem ruangan lab k, jam 10.00-12.20 untuk membuat web
# Antrian terdepan: Era minjem ruangan 515, jam 10.00-12.20 untuk rapat organisasi
# Sudah di proses: Era minjem ruangan 515, jam 10.00-12.20 untuk rapat organisasi
#
#  Daftar antrian peminjaman:
# 1 . Wilsa minjem ruangan 331, jam 07.30-10.00 untuk kelas pengganti
# 2 . ceri minjem ruangan lab k, jam 10.00-12.20 untuk membuat web
